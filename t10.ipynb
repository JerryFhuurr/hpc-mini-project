# %%
# !nsys profile -o double_prof python t9_cupy_simulate.py 100
# Out:
# ...
# Generating 'C:\Users\14349\AppData\Local\Temp\nsys-report-7ecf.qdstrm'
#
# [1/1] [0%                          ] nsys-report-4f67.nsys-rep
# [1/1] [0%                          ] nsys-report-4f67.nsys-rep
# [1/1] [===================82%      ] nsys-report-4f67.nsys-rep
# [1/1] [========================100%] nsys-report-4f67.nsys-rep
# [1/1] [========================100%] nsys-report-4f67.nsys-rep
# Generated:
# 	C:\Users\14349\AppData\Local\Temp\nsys-report-4f67.nsys-rep
# WARNING: CPU context switches trace requires administrative privileges, disabling.
# WARNING: CPU sampling requires administrative privileges, disabling.
# Failed to create 'c:\Users\14349\hpc\123\modified_swiss_dwellings\double_prof.nsys-rep': File exists.
# Use `--force-overwrite true` to overwrite existing files.

# %%
# !nsys stats double_prof.nsys-rep
# Out:
# NOTICE: Existing SQLite export found: double_prof.sqlite
#         It is assumed file was previously exported from: double_prof.nsys-rep
#         Consider using --force-export=true if needed.
#
# Processing [double_prof.sqlite] with [C:\Program Files\NVIDIA Corporation\Nsight Systems 2025.2.1\host-windows-x64\reports\nvtx_sum.py]...
# SKIPPED: double_prof.sqlite does not contain NV Tools Extension (NVTX) data.
#
# Processing [double_prof.sqlite] with [C:\Program Files\NVIDIA Corporation\Nsight Systems 2025.2.1\host-windows-x64\reports\osrt_sum.py]...
#
#  ** OS Runtime Summary (osrt_sum):
#
# Report was successfully run, but no data was returned.
#
# Processing [double_prof.sqlite] with [C:\Program Files\NVIDIA Corporation\Nsight Systems 2025.2.1\host-windows-x64\reports\cuda_api_sum.py]...
#
#  ** CUDA API Summary (cuda_api_sum):
#
#  Time (%)  Total Time (ns)  Num Calls   Avg (ns)     Med (ns)    Min (ns)   Max (ns)   StdDev (ns)              Name
# ...
